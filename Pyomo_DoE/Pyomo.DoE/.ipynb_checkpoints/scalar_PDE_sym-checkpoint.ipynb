# %%
from pyomo.dae import ContinuousSet, DerivativeVar
import pyomo.environ as pyo
from pyomo.contrib.doe import DesignOfExperiments
import numpy as np


class scalarPDE:
    """
    1D diffusion PDE with:
    - left boundary heat flux control u(t)
    - right boundary insulated (no flux)
    - uniform initial temperature T0
    Structured so DesignOfExperiments can call get_labeled_model().
    """

    def __init__(self, data, nfe_t, ncp_t, nfe_x, ncp_x):
        self.data   = data
        self.nfe_t  = nfe_t
        self.ncp_t  = ncp_t
        self.nfe_x  = nfe_x
        self.ncp_x  = ncp_x
        self.model  = None

    def get_labeled_model(self):
        if self.model is None:
            self._create_model()
            self._finalize_model()
            self._label_experiment()
        return self.model

    def _create_model(self):
        m = self.model = pyo.ConcreteModel()

        # pull time horizon from data
        t_lo = min(self.data["t_range"])
        t_hi = max(self.data["t_range"])

        # domains
        m.t = ContinuousSet(bounds=[t_lo, t_hi])
        m.x_space = ContinuousSet(bounds=[0.0, 1.0])

        # fields
        m.T = pyo.Var(m.x_space, m.t, within=pyo.Reals)   # temperature
        m.u = pyo.Var(m.t, within=pyo.Reals)              # boundary flux control

        # unknown parameter to estimate
        m.alpha = pyo.Var(within=pyo.Reals)

        # keep these params in case you want convection again later
        m.h   = pyo.Param(initialize=self.data["h"],  mutable=False)
        m.T_c = pyo.Param(initialize=self.data["Tc"], mutable=False)

        # design var: uniform IC
        m.T0 = pyo.Var(initialize=self.data["T0"], within=pyo.Reals)

        # time and space derivatives
        m.dTdt   = DerivativeVar(m.T, wrt=m.t)
        m.dTdx   = DerivativeVar(m.T, wrt=m.x_space)
        m.d2Tdx2 = DerivativeVar(m.dTdx, wrt=m.x_space)

        # interior PDE (skip boundaries in x)
        @m.Constraint(m.x_space, m.t)
        def pde_eqn(m, x, t):
            xL = m.x_space.first()
            xR = m.x_space.last()
            if (x == xL) or (x == xR):
                return pyo.Constraint.Skip
            return m.dTdt[x, t] == m.alpha * m.d2Tdx2[x, t]

        # NOTE: do not assign m.pde_eqn = pde_eqn  (Pyomo already attached it)

        # boundary conditions get added in _finalize_model()

    def _finalize_model(self):
        m = self.model

        # -------------------
        # unpack data
        # -------------------
        control_points = self.data["control_points"]     # dict {t_ctrl: u_guess}
        t_range        = self.data["t_range"]            # list
        u_bounds       = self.data["u_bounds"]           # (umin, umax)
        alpha_nominal  = self.data["alpha_nominal"]      # float
        x_range        = self.data.get("x_range", None)  # optional list
        x_sensor_val   = self.data.get("x_sensor", 0.5)  # sensor location

        # -------------------
        # augment spatial grid before discretization
        # -------------------
        if x_range is not None:
            for xv in x_range:
                m.x_space.update([xv])

        # ensure sensor is included
        if x_sensor_val not in list(m.x_space):
            m.x_space.update([x_sensor_val])

        # boundary nodes
        x_left_val  = min(list(m.x_space))
        x_right_val = max(list(m.x_space))

        # -------------------
        # augment time grid before discretization
        # -------------------
        for tt in t_range:
            m.t.update([tt])
        for tt in control_points.keys():
            m.t.update([tt])

        # control times as an ordered Set
        m.t_control = pyo.Set(
            initialize=list(control_points.keys()),
            ordered=True,
        )

        # -------------------
        # fix alpha to nominal
        # -------------------
        m.alpha.fix(alpha_nominal)

        # -------------------
        # bounds on T0
        # -------------------
        if "T0_bounds" in self.data:
            Tmin, Tmax = self.data["T0_bounds"]
            m.T0.setlb(Tmin)
            m.T0.setub(Tmax)

        # -------------------
        # bounds + init for u(t)
        # -------------------
        umin, umax = u_bounds
        for t in m.t:
            m.u[t].setlb(umin)
            m.u[t].setub(umax)

            # step-wise constant guess using last control point <= t
            prev_ctrl_times = [tc for tc in control_points if tc <= t]
            if len(prev_ctrl_times) == 0:
                first_tc = min(control_points.keys())
                m.u[t].value = control_points[first_tc]
            else:
                last_tc = max(prev_ctrl_times)
                m.u[t].value = control_points[last_tc]

        # enforce piecewise-constant control between control points
        @m.Constraint(m.t - m.t_control)
        def u_hold(m, t):
            prev_tc = max(tc for tc in m.t_control if tc < t)
            return m.u[t] == m.u[prev_tc]
        # do NOT overwrite m.u_hold = u_hold

        # -------------------
        # boundary conditions
        # -------------------

        # left: flux BC, matches the control
        @m.Constraint(m.t)
        def left_bc(m, t):
            return m.dTdx[x_left_val, t] == -m.u[t]

        # right: insulated (Neumann = 0), to be compatible with uniform T0
        @m.Constraint(m.t)
        def right_bc(m, t):
            return m.dTdx[x_right_val, t] == 0.0

        # -------------------
        # store special nodes
        # -------------------
        m.x_sensor     = pyo.Param(initialize=x_sensor_val,  mutable=False)
        m.x_left_node  = pyo.Param(initialize=x_left_val,    mutable=False)
        m.x_right_node = pyo.Param(initialize=x_right_val,   mutable=False)

        # -------------------
        # discretize space then time
        # -------------------
        disc_space = pyo.TransformationFactory("dae.collocation")
        disc_space.apply_to(
            m,
            wrt=m.x_space,
            nfe=self.nfe_x,
            ncp=self.ncp_x,
        )

        disc_time = pyo.TransformationFactory("dae.collocation")
        disc_time.apply_to(
            m,
            wrt=m.t,
            nfe=self.nfe_t,
            ncp=self.ncp_t,
        )

        # -------------------
        # initial condition T(x, t0) = T0
        # -------------------
        t0 = min(list(m.t))
        T0_val = pyo.value(m.T0)
        for x in m.x_space:
            m.T[x, t0].fix(T0_val)

    def _label_experiment(self):
        m = self.model

        # measured outputs
        m.experiment_outputs = pyo.Suffix(direction=pyo.Suffix.LOCAL)
        x_s = pyo.value(m.x_sensor)
        for t_m in m.t_control:
            m.experiment_outputs[m.T[x_s, t_m]] = None
        print(len(m.experiment_outputs))
        # measurement error
        m.measurement_error = pyo.Suffix(direction=pyo.Suffix.LOCAL)
        meas_err = 1e-2
        for t_m in m.t_control:
            m.measurement_error[m.T[x_s, t_m]] = meas_err

       
        m.measurement_error.update((m.T[x_s, t_m], meas_err) for t in m.t_control)

        print(len(m.measurement_error))

        # experiment inputs (design variables)
        m.experiment_inputs = pyo.Suffix(direction=pyo.Suffix.LOCAL)
        m.experiment_inputs[m.T0] = None
        # for t_ctrl in m.t_control:
        #     m.experiment_inputs[m.u[t_ctrl]] = None

        # unknown parameter we're designing for
        m.unknown_parameters = pyo.Suffix(direction=pyo.Suffix.LOCAL)
        m.unknown_parameters[m.alpha] = pyo.value(m.alpha)


# --------------------------
# data for the PDE experiment
# --------------------------

# make ALL control points 0.0 to avoid forcing gradients at t≈0
flat_u = {
    0.0:   0.5,
    0.125: 0.5,
    0.25:  0.5,
    0.375: 0.5,
    0.5:   0,
    0.625: -0.5,
    0.75:  -0.2,
    0.875: -0.5,
    1.0:   -0.5,
}

data_pde = {
    "x_range":   [0.0, 0.25, 0.5, 0.75, 1.0],
    "x_sensor":  0.5,
    "t_range":   [0.0, 0.125, 0.25, 0.375, 0.5, 0.625, 0.75, 0.875, 1.0],

    "control_points": flat_u,
    "u_bounds": (-1.0, 1.0),

    "T0": 0.5,
    "T0_bounds": (0.5, 2.0),

    "h": 0.2,
    "Tc": 0.5,
    "alpha_nominal": 0.5,
}

# discretization
nfe_x = 5
ncp_x = 5
nfe_t = 8
ncp_t = 8


# wrapper class to satisfy DesignOfExperiments API
class ExperimentWrapper:
    def __init__(self, exp_obj):
        self._exp = exp_obj
    def get_labeled_model(self):
        return self._exp.get_labeled_model()


# build wrapped experiment
pde_expt = scalarPDE(
    data=data_pde,
    nfe_t=nfe_t,
    ncp_t=ncp_t,
    nfe_x=nfe_x,
    ncp_x=ncp_x,
)
wrapped_expt = ExperimentWrapper(pde_expt)

# DoE setup
fd_formula = "central"
step_size = 1e-3
objective_option = "determinant"
scale_nominal_param_value = True




doe_obj = DesignOfExperiments(
    wrapped_expt,
    fd_formula=fd_formula,
    step=step_size,
    objective_option=objective_option,
    gradient_method = "pynumero",
    scale_constant_value=1,
    scale_nominal_param_value=scale_nominal_param_value,
    prior_FIM=None,
    jac_initial=None,
    fim_initial=None,
    L_diagonal_lower_bound=1e-7,
    solver=pyo.SolverFactory("ipopt"),
    tee=False,
    get_labeled_model_args=None,
    _Cholesky_option=True,
    _only_compute_fim_lower=True,
)

# expt0 = doe_obj.model.scenario_blocks[0]  # created by DoE
# cons = [c for c in expt0.component_data_objects(pyo.Constraint, active=True)]
# vars_ = [v for v in expt0.component_data_objects(pyo.Var, active=True) if not v.fixed]
# n_params = sum(1 for _ in expt0.model().unknown_parameters)  # DoE stores suffix on the base
# print(f"[diag] free vars={len(vars_)}, cons={len(cons)}, params={n_params}")

# run DoE
doe_obj.run_doe()

# report results
print("Optimal experiment values:")
opt_design = doe_obj.results["Experiment Design"]

if len(opt_design) > 0:
    print(f"\tInitial temperature T0*: {opt_design[0]:.4f}")

if len(opt_design) > 1:
    u_list = opt_design[1:]
    print(
        "\tControl inputs u(t_ctrl)*: ["
        + ", ".join(f"{val:.4f}" for val in u_list)
        + "]"
    )

print("FIM at optimal design:")
print(np.array(doe_obj.results["FIM"]))

print("Objective value at optimal design:",
      pyo.value(doe_obj.model.objective))

print("Experiment Design Names:", doe_obj.results["Experiment Design Names"])
print("Solve time (s):", doe_obj.results["Solve Time"])
print("Build time (s):", doe_obj.results["Build Time"])
print("Initialization time (s):", doe_obj.results["Initialization Time"])
print("Total wall time (s):", doe_obj.results["Wall-clock Time"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 318
#     294 scale_nominal_param_value = True
#     299 doe_obj = DesignOfExperiments(
#     300     wrapped_expt,
#     301     fd_formula=fd_formula,
#    (...)    315     _only_compute_fim_lower=True,
#     316 )
# --> 318 expt0 = doe_obj.model.scenario_blocks[0]  # created by DoE
#     319 cons = [c for c in expt0.component_data_objects(pyo.Constraint, active=True)]
#     320 vars_ = [v for v in expt0.component_data_objects(pyo.Var, active=True) if not v.fixed]
#
# File /opt/anaconda3/envs/pyomosym/lib/python3.11/site-packages/pyomo/core/base/block.py:550, in BlockData.__getattr__(self, val)
#     547     return _component_decorator(self, ModelComponentFactory.get_class(val))
#     548 # Since the base classes don't support getattr, we can just
#     549 # throw the "normal" AttributeError
# --> 550 raise AttributeError(
#     551     "'%s' object has no attribute '%s'" % (self.__class__.__name__, val)
#     552 )
#
# AttributeError: 'ConcreteModel' object has no attribute 'scenario_blocks'
